# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE =np.square(np.subtract(y,yp)).mean()
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 215.539
# The Mean absolute error is 11.603

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# From: Dataset, Shared Cars Locations
#
# 1. 你選的這組資料為何重要
# 這是以色列特拉維夫市所推出的共享汽車計畫(AutoTel), 為了減少全市的汽車使用數量與解決汽車停車場問題, 這也是目前現代化都市都會面臨的問題, 可以參考作為借鑑。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 資料來自AutoTel官網(https://en.autotel.co.il/en/), 時間區間是2018.12.11～2019.1.10, 每兩分鐘抽出一次停放汽車的位置, 原始數據先以CSV格式存到Google storage,再轉到Google BigQuery。
#
# 3. 蒐集而來的資料型態為何
# 資料型態包含timestamp, latitude, longitude, total_cars, carsList
#
# 4. 這組資料想解決的問題如何評估
# 這組資料想預測與合理調配可用的汽車數量, 評估與調整地理位置需求(城市-需求量大或郊區-需求量少), 預測合適的業務模型。
# 例如，可以修改價格，使在高需求區域停放汽車的使用費更便宜，或利用運輸計劃，
# 以便從低需求區域收集汽車返回高需求區域。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 核心問題為在熱門時段增加載客人數, 以提升業績。可分析這個城市的熱門搭車時段與主要載客地點(如捷運站), 增加載客率與載客次數。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 基本上先從政府資料開放平台收集, 以台北市為例, 包含臺北捷運各站分時進出量統計、臺北市自行車租借紀錄、臺北捷運全系統旅運量統計等, 進行資料收集。
#
# 3. 蒐集而來的資料型態為何
# 主要欄位包含日期、分時、起迄車站位置、進出量等
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 評估每日熱門搭車時段的載客量與載客次數, 另外考慮交通時間(如塞車的影響), 另評估集中在主要載客地點是否有增加營收。
